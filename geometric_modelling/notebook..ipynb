# %%
import os
import seaborn as sns
import seaborn
import array
import numpy as np
import re, seaborn as sns, numpy as np, pandas as pd, random
from pylab import *
from matplotlib.pyplot import plot, show, draw, figure, cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math
# from matplotlib import pyplot as plt
import pandas as pd
import subprocess
import shutil
from main import *
# just the first function

# %%
df4 = pd.read_csv("_6_output_nodes.txt", header=None)
df5 = pd.read_csv("South_force.csv", header=None)
df4.columns = ['1','2', '3','4','5','6']
x_1 = df4['3']
y_1 = df4['4']
z_1 = df4['5']
stress = df4['6']
print(df4.head)
z_1
# Out:
# <bound method NDFrame.head of      1     2          3          4          5          6
# 0    0  4999  21.684855  21.792095 -21.845749  21.792095
# 1    1  2950  20.940260  19.059740 -21.493927  19.059740
# 2    2   583  10.717854  28.498791 -11.109531  28.498791
# 3    3  5159  23.025868  17.047409 -23.303669  17.047409
# 4    4  3125  16.206787  16.788094 -16.497440  16.788094
# 5    5  3120  14.996520  14.373730 -14.685124  14.373730
# 6    6  5426  27.378403  12.804256 -26.943098  12.804256
# 7    7  5305  12.173051  12.173248 -12.610472  12.173248
# 8    8  5336  17.734589  17.782715 -17.677559  17.782715
# 9    9  5022  20.087185  19.100077 -20.315645  19.100077
# 10  10  5338  17.706217  17.739231 -22.277273  17.739231
# 11  11  5559  16.640303  23.473450 -23.416574  23.473450
# 12  12  5295  15.888090  24.029827 -15.849422  24.029827
# 13  13  5308  23.038010  23.143436 -16.909281  23.143436
# 14  14  4310  24.428310  24.428310 -25.320066  24.428310
# ...

# %%
# import seaborn as seaborn
import matplotlib.pyplot as plot
import numpy as np

seaborn.set_style("darkgrid")

mean = 3
number =50

plot.figure(figsize=(10,20.5))
axes = plot.axes(projection='3d')
print(type(axes))
# axes.scatter3D(x_1, y_1, z_1)

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_zlabel('z')
#make points bigger
# seaborn make the point color vary with z
axes.scatter(x_1, y_1, z_1, c=stress, cmap='Wistia', s=300)

#red points seaborn
axes.scatter3D(x_1, y_1, z_1, s=300 ,c='r', marker='o')

axes.view_init(45, 215)
plot.show()

# list counting from 0 to 22
# list_1 = list(range(0,23))
# Out:
# <class 'matplotlib.axes._subplots.Axes3DSubplot'>

# %%
plt.figure(figsize=(10,5))
plt.xlim(10,30)
plt.xlabel('Price')
plt.ylabel('Records')
sns.distplot(x_1,bins=30,kde=False)
plt.show()

# amke for me a list that starts at zero and ends at at 1998
# list_1 = list(range(0,1998))
# iloc for a whole row extraction
# df1.iloc[0]
column 1
# Out:
#   Input In [46]
#     column 1
#            ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# df = pd.DataFrame(np.random.rand(100, 5), columns=["a", "b", "c", "d", "e"])

# %%
profile = ProfileReport(df4, title="Pandas Profiling Report")

# %%
profile.to_widgets()
# pandas save csv space separated
# df4.to_csv('_6_output_nodes.csv', sep=',', index=False)
# df5.to_csv('South_force.csv', sep=',', index=False)
# df4.to_csv('_6_output_nodes.txt', sep=' ', index=False)
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
profile.to_file("your_report.html")
#save a list to file
# with open('_6_output_nodes.txt', 'w') as f:
#     for item in x_1:
#         f.write("%s\n" % item)
# with open('South_force.csv', 'w') as f:
#     for item in y_1:
#         f.write("%s\n" % item)
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_notebook_iframe()
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-08-17 14:19:48.023091&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
